# %%
#Intall necessary modules and import required packages
import nltk
import random
import json
import pickle
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
#To parse the JSON file into python we used JSON package
d_file = open('intents.json').read()
intents = json.loads(d_file)
all_words=[]
all_classes = []
all_documents = []
ignore_words = ['?', '!']

# %%
def processing_data(pattern):
   #fetch patterns and tokenize them into words
   self.pattern=list(map(lambda x:x["patterns"],self.intents))
   self.words=list(map(word_tokenize,flatten(self.pattern)))

# %%
#preprocessing the data
#before making a model we pwerformed various preprocessing techniques
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #By fetching the patters we tokenized the data: using nltk.word_tokenize().
        wd_tokens = nltk.word_tokenize(pattern)
        all_words.extend(wd_tokens)
        #append words in the word list
        all_documents.append((wd_tokens, intent['tag']))

        #we created list of classes  for tags
        if intent['tag'] not in all_classes:
            all_classes.append(intent['tag'])

# %%
# We lemmatized and lowered each word and removed duplicates by creating a pickle file
all_words = [lemmatizer.lemmatize(wd_tokens.lower()) for wd_tokens in all_words if wd_tokens not in ignore_words]
all_words = sorted(list(set(all_words)))
# all classes are sorted
all_classes = sorted(list(set(all_classes)))
# documents is combination between intents and patterns
print (len(all_documents), "all_documents")
# now classes = intents
print (len(all_classes), "all_classes", all_classes)
# words is all words and vocabulary
print (len(all_words), "unique lemmatized words", all_words)


pickle.dump(all_words,open('all_words.pkl','wb'))
pickle.dump(all_classes,open('all_classes.pkl','wb'))
# Out:
# 364 all_documents
# 55 all_classes ['ABM procedures', 'Academic calendar', 'Admissions', 'Alumni', 'CAAS Staff', 'CAAS services', 'CECIL C. HUMPHREYS SCHOOL OF LAW', 'Canvas', 'Combination Senior Program Guide', 'Contact number', 'Course', 'Current students', 'Explore UofM', 'Faculty and staff', 'Fees', 'Grades', 'Graduate Certificate Programs', 'Graduate Non-Degree Status', 'Graduate catalog', 'Holds', 'Hours of operation', 'International admissions', 'Libraries', 'Location', 'Mymemphis', 'Nationally Ranked Graduate Programs', 'News and events', 'Registration', 'Reverse transfer', 'Transcripts', 'University ID', 'University Residence', 'about', 'academic advisor', 'apply to UofM', 'attendance', 'center for athletic academic services', 'commencement', 'complaint', 'contact graduation analyst', 'degree programs', 'freashman application fee waiver', 'goodbye', 'greeting', 'help', 'law admissions', 'name', 'personal data', 'readmission', 'self service guide', 'student schedule', 'thanks', 'undergraduate catalog', 'vetarians', 'withdraw']
# 256 unique lemmatized words ["'s", 'a', 'abm', 'about', 'academic', 'acceptance', 'account', 'add', 'address', 'admission', 'advisor', 'after', 'age', 'alumnus', 'and', 'any', 'anyone', 'application', 'apply', 'are', 'ask', 'assignment', 'at', 'athletic', 'attend', 'attendance', 'available', 'be', 'birth', 'bye', 'c.', 'caas', 'calculate', 'calculator', 'calendar', 'call', 'campus', 'can', 'canvas', 'catalog', 'cecil', 'center', 'certificate', 'change', 'check', 'class', 'clear', 'combination', 'come', 'commencement', 'complaint', 'computer', 'connect', 'contact', 'could', 'course', 'current', 'data', 'datascience', 'date', 'day', 'deadline', 'degree', 'do', 'dob', 'doctoral', 'dofb', 'drop', 'dropping', 'each', 'eligibility', 'engineering', 'event', 'exam', 'experience', 'explore', 'facility', 'faculty', 'fee', 'finance', 'find', 'first', 'for', 'freashers', 'freashman', 'freashmen', 'from', 'get', 'give', 'goodbye', 'gpa', 'grade', 'gradschool', 'graduate', 'graduation', 'guide', 'guy', 'hand', 'have', 'hay', 'hello', 'help', 'helpful', 'hey', 'hi', 'highschool', 'hold', 'hour', 'housing', 'how', 'human', 'humphreys', 'i', 'id', 'in', 'info', 'information', 'international', 'into', 'is', 'know', 'later', 'latest', 'law', 'lawschool', 'learning', 'librarien', 'library', 'life', 'list', 'located', 'location', 'login', 'm', 'management', 'master', 'me', 'memphis', 'military', 'missed', 'more', 'much', 'my', 'mymemphis', 'name', 'national', 'nationally', 'need', 'news', 'no', 'non', 'non-degree', 'number', 'of', 'offer', 'offered', 'official', 'on', 'oncampus', 'online', 'open', 'operation', 'or', 'page', 'pay', 'per', 'personal', 'phone', 'platform', 'please', 'procedure', 'process', 'professor', 'profile', 'program', 'qualification', 'raise', 'rank', 'ranked', 'ranking', 'reach', 'readmission', 'readmits', 'record', 'register', 'registration', 'report', 'research', 'residence', 'residency', 'resource', 'reverse', 'saturday', 'schedule', 'school', 'science', 'see', 'seeking', 'self', 'semester', 'senior', 'service', 'should', 'something', 'sophomore', 'staff', 'status', 'student', 'submit', 'support', 'system', 'telephone', 'tell', 'term', 'thank', 'thanks', 'that', 'the', 'there', 'time', 'timing', 'to', 'tour', 'transcript', 'transfer', 'type', 'u', 'ug', 'uid', 'undergraduate', 'university', 'unofficial', 'uofm', 'update', 'vetarians', 'view', 'virtual', 'waiver', 'want', 'wellness', 'what', 'whats', 'when', 'where', 'wheres', 'which', 'who', 'will', 'with', 'withdraw', 'withdrawal', 'withdrawing', 'working', 'year', 'you', 'your']

# %%
# We created training and test data
training_data = []
# We created empty array for output
empty_array = [0] * len(all_classes)
# for each sentence we initialized bag of words and training set
for doc in all_documents:
    # we initialized bag of words
    bag = []
    # For the pattern - list of tokenized words
    pattern_words = doc[0]
    # To represent related words-  lemmatize each word and create base word, 
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # we created bag of words array with 1, if word found in the current pattern
    for wd_tokens in all_words:
        bag.append(1) if wd_tokens in pattern_words else bag.append(0)
    
    # The output will be '0' for each tag and '1' for current tag for each pattern
    output_row = list(empty_array)
    output_row[all_classes.index(doc[1])] = 1
    
    training_data.append([bag, output_row])
# we shuffled features and turned them into np.array
random.shuffle(training_data)
training_data = np.array(training_data)
# and then we created train and test lists. X as patterns, Y as intents
train_x = list(training_data[:,0])
train_y = list(training_data[:,1])
print("created training data")

#Model building

# we created a model which is a deep neural network with three layers. First layer has 128 neurons, second layer has 64 neurons and third is output layer which containes contains number of neurons
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile the model. This model give good results.
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#We finally fit and saved the modelas chatbot_model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('uofmchatbot_model', hist)

print("model is created and saved as uofmchatbot_model")
# Out:
# created training data
# Epoch 1/200
# C:\Users\vijay\AppData\Local\Temp\ipykernel_17100\3473384675.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training_data = np.array(training_data)
# C:\Users\vijay\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#
200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8599
# Epoch 59/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8709
# Epoch 60/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.8214
# Epoch 61/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.8489
# Epoch 62/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.8462
# Epoch 63/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.8599
# Epoch 64/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8489
# Epoch 65/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8516
# Epoch 66/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.8571
# Epoch 67/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8462
# Epoch 68/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8599
# Epoch 69/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8819
# Epoch 70/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8571
# Epoch 71/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8819
# Epoch 72/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8709
# Epoch 73/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8654
# Epoch 74/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8654
# Epoch 75/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8736
# Epoch 76/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8544
# Epoch 77/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8352
# Epoch 78/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.8324
# Epoch 79/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.8489
# Epoch 80/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8681
# Epoch 81/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.9011
# Epoch 82/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8626
# Epoch 83/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8736
# Epoch 84/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3526 - accuracy: 0.8709
# Epoch 85/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3600 - accuracy: 0.8791
# Epoch 86/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8434
# Epoch 87/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3075 - accuracy: 0.8874
# Epoch 88/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8819
# Epoch 89/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2955 - accuracy: 0.8901
# Epoch 90/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8874
# Epoch 91/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8764
# Epoch 92/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.8819
# Epoch 93/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8599
# Epoch 94/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.9011
# Epoch 95/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8819
# Epoch 96/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.8764
# Epoch 97/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2906 - accuracy: 0.8956
# Epoch 98/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.8846
# Epoch 99/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8846
# Epoch 100/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3059 - accuracy: 0.8956
# Epoch 101/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2908 - accuracy: 0.8929
# Epoch 102/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8874
# Epoch 103/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8736
# Epoch 104/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.8764
# Epoch 105/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2947 - accuracy: 0.8984
# Epoch 106/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.8984
# Epoch 107/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3150 - accuracy: 0.8929
# Epoch 108/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3094 - accuracy: 0.8846
# Epoch 109/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8599
# Epoch 110/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8681
# Epoch 111/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8956
# Epoch 112/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3129 - accuracy: 0.8874
# Epoch 113/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2871 - accuracy: 0.8791
# Epoch 114/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.8709
# Epoch 115/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.8764
# Epoch 116/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.8654
# Epoch 117/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2734 - accuracy: 0.9011
# Epoch 118/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8984
# Epoch 119/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3154 - accuracy: 0.8736
# Epoch 120/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8874
# Epoch 121/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2980 - accuracy: 0.8791
# Epoch 122/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9011
# Epoch 123/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3005 - accuracy: 0.8791
# Epoch 124/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8626
# Epoch 125/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.8544
# Epoch 126/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8709
# Epoch 127/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.8846
# Epoch 128/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8984
# Epoch 129/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.8626
# Epoch 130/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.8929
# Epoch 131/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.9011
# Epoch 132/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.8819
# Epoch 133/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3127 - accuracy: 0.8901
# Epoch 134/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8984
# Epoch 135/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2948 - accuracy: 0.9011
# Epoch 136/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2218 - accuracy: 0.9231
# Epoch 137/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2903 - accuracy: 0.8626
# Epoch 138/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.9011
# Epoch 139/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8681
# Epoch 140/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8791
# Epoch 141/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8709
# Epoch 142/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3212 - accuracy: 0.8901
# Epoch 143/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.8929
# Epoch 144/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.8819
# Epoch 145/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8929
# Epoch 146/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8709
# Epoch 147/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8984
# Epoch 148/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3220 - accuracy: 0.8764
# Epoch 149/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.9011
# Epoch 150/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8819
# Epoch 151/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.8846
# Epoch 152/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.8984
# Epoch 153/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 0.8819
# Epoch 154/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2886 - accuracy: 0.8984
# Epoch 155/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8846
# Epoch 156/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9093
# Epoch 157/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.8956
# Epoch 158/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 0.8736
# Epoch 159/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8626
# Epoch 160/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2481 - accuracy: 0.9203
# Epoch 161/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.8819
# Epoch 162/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9176
# Epoch 163/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.9038
# Epoch 164/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.8819
# Epoch 165/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.8929
# Epoch 166/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.8929
# Epoch 167/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3083 - accuracy: 0.8901
# Epoch 168/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.8681
# Epoch 169/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8846
# Epoch 170/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.8819
# Epoch 171/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.9203
# Epoch 172/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.9066
# Epoch 173/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.8819
# Epoch 174/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.9066
# Epoch 175/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9066
# Epoch 176/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.9038
# Epoch 177/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.8929
# Epoch 178/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9093
# Epoch 179/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.8901
# Epoch 180/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2046 - accuracy: 0.9231
# Epoch 181/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.9121
# Epoch 182/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2792 - accuracy: 0.8819
# Epoch 183/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.8956
# Epoch 184/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3099 - accuracy: 0.8571
# Epoch 185/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.8874
# Epoch 186/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.8984
# Epoch 187/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8846
# Epoch 188/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.8874
# Epoch 189/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2842 - accuracy: 0.9121
# Epoch 190/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9038
# Epoch 191/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.8929
# Epoch 192/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.8901
# Epoch 193/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3168 - accuracy: 0.8901
# Epoch 194/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2984 - accuracy: 0.8929
# Epoch 195/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9286
# Epoch 196/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.9313
# Epoch 197/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.8956
# Epoch 198/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.8929
# Epoch 199/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8489
# Epoch 200/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.8984
# INFO:tensorflow:Assets written to: uofmchatbot_model\assets
# model is created and saved as uofmchatbot_model
